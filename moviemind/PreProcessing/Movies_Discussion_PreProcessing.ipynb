# %% [markdown]
# # Importing the dependencies

# %%
import pandas as pd
import sqlite3
import re

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException, NoSuchElementException
from bs4 import BeautifulSoup 

from tmdbv3api import TMDb
import requests

import google.generativeai as genai
from youtube_transcript_api import YouTubeTranscriptApi

import os
import time
from dotenv import load_dotenv


load_dotenv()
GOOGLE_API_KEY_MOVIE_RECOMMENDER = os.getenv("GOOGLE_API_KEY_MOVIE_RECOMMENDER")
TMDB_API_KEY = os.getenv("TMDB_API_KEY")
genai.configure(api_key=GOOGLE_API_KEY_MOVIE_RECOMMENDER)

# %% [markdown]
# # Loading the dataset

# %%
database = "../SQL_Database/Movies.db"

database_key_based = pd.read_sql_query("SELECT m.* FROM Movies_Key_Based AS m", sqlite3.connect(database))
database_query_based = pd.read_sql_query("SELECT m.* FROM Movies_Database AS m", sqlite3.connect(database))

# %%
database_key_based.head()
# Out:
#        id                           title  \
# 0  283995  Guardians of the Galaxy Vol. 2
# 1  480530                        Creed II
# 2  299536          Avengers: Infinity War
# 3  299534               Avengers: Endgame
# 4  337167              Fifty Shades Freed
#
#                                             keywords  \
# 0  ['demi god', 'alien creature', 'sarcasm', 'cra...
# 1  ['baby', 'training montage', 'sequel', 'boxing...
# 2  ['superhero', 'ensemble cast', 'marvel cinemat...
# 3  ['time travel', 'superhero', 'super villain', ...
# 4  ['sex scene', 'wedding ceremony', 'bondage', '...
#
#                                       review_summary  \
# 0  Guardians of the Galaxy Vol. 2 elicited a gene...
# 1  Creed II elicits a mixed response from audienc...
# 2  Avengers: Infinity War elicits a generally pos...
# 3  Avengers: Endgame elicited a largely positive ...
# 4  The audience reaction to Fifty Shades Freed is...
#
#                                                 tags  \
# 0  adventure action sci-fi chris pratt zoe saldañ...
# 1  drama michael b. jordan sylvester stallone tes...
# 2  adventure action sci-fi robert downey jr. chri...
# 3  adventure sci-fi action robert downey jr. chri...
# 4  drama romance dakota johnson jamie dornan eric...
#
#                                           embeddings
# 0  [-0.010018928121777062, -0.042597577593544884,...
# 1  [-0.012480250747134571, -0.02905849380429892, ...
# 2  [-0.01140899767743463, -0.027857139652446076, ...
# 3  [-0.00412223552630982, -0.031019326010432745, ...
# 4  [-0.0075680177194708525, -0.024964091224630152...

# %%
database_query_based.head()
# Out:
#        id    IMDB_ID                           title  release_year  \
# 0  283995  tt3896198  Guardians of the Galaxy Vol. 2          2017
# 1  480530  tt6343314                        Creed II          2018
# 2  299536  tt4154756          Avengers: Infinity War          2018
# 3  299534  tt4154796               Avengers: Endgame          2019
# 4  337167  tt4477536              Fifty Shades Freed          2018
#
#                               genres  vote_average  \
# 0  ['Adventure', 'Action', 'Sci-Fi']         7.623
# 1                          ['Drama']         6.990
# 2  ['Adventure', 'Action', 'Sci-Fi']         8.260
# 3  ['Adventure', 'Sci-Fi', 'Action']         8.268
# 4               ['Drama', 'Romance']         6.699
#
#                                                 cast                Director  \
# 0  ['Chris Pratt', 'Zoe Saldaña', 'Dave Bautista'...              James Gunn
# 1  ['Michael B. Jordan', 'Sylvester Stallone', 'T...        Steven Caple Jr.
# 2  ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark...  Anthony RussoJoe Russo
# 3  ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruf...  Anthony RussoJoe Russo
# 4  ['Dakota Johnson', 'Jamie Dornan', 'Eric Johns...             James Foley
#
#                                             keywords  \
# 0  ['demi god', 'alien creature', 'sarcasm', 'cra...
# 1  ['baby', 'training montage', 'sequel', 'boxing...
# 2  ['superhero', 'ensemble cast', 'marvel cinemat...
# 3  ['time travel', 'superhero', 'super villain', ...
# 4  ['sex scene', 'wedding ceremony', 'bondage', '...
#
#                                              reviews  \
# 0  ["Despite being a huge comic book nerd I was n...
# 1  ["This movie is not as good as the first Creed...
# 2  ["Avengers infinity war is an emotional roller...
# 3  ["But its a pretty good film. A bit of a mess ...
# 4  ["The first of the three that is actually emot...
#
#                                     review_sentiment  \
# 0  ['positive', 'positive', 'positive', 'positive...
# 1  ['negative', 'positive', 'positive', 'positive...
# 2  ['positive', 'positive', 'positive', 'positive...
# 3  ['positive', 'positive', 'positive', 'positive...
# 4  ['positive', 'negative', 'negative', 'negative...
#
#                                       review_summary  \
# 0  Guardians of the Galaxy Vol. 2 elicited a gene...
# 1  Creed II elicits a mixed response from audienc...
# 2  Avengers: Infinity War elicits a generally pos...
# 3  Avengers: Endgame elicited a largely positive ...
# 4  The audience reaction to Fifty Shades Freed is...
#
#                         poster_path                     backdrop_path
# 0  /y4MBh0EjBlMuOzv9axM4qJlmhzz.jpg  /aJn9XeesqsrSLKcHfHP4u5985hn.jpg
# 1  /v3QyboWRoA4O9RbcsqH8tJMe8EB.jpg  /xTYGN1b3XkOtODryXTKgdXLtPMz.jpg
# 2  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 3  /or06FN3Dka5tukK1e9sl16pB3iy.jpg  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 4  /9ZedQHPQVveaIYmDSTazhT3y273.jpg  /9ywA15OAiwjSTvg3cBs9B7kOCBF.jpg

# %%
database_query_based.tail()
# Out:
#          id    IMDB_ID                                              title  \
# 909  484889  tt6076226                          Rise of the Footsoldier 3
# 910  592230  tt7394674                                      Blood Quantum
# 911  574638  tt9577852  Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 912  299782  tt0069049                         The Other Side of the Wind
# 913  431093  tt5537228                           Everybody Loves Somebody
#
#      release_year                                    genres  vote_average  \
# 909          2017  ['Action', 'Crime', 'Drama', 'Thriller']           6.3
# 910          2019                                ['Horror']           5.8
# 911          2019                  ['Documentary', 'Music']           7.1
# 912          2018                                 ['Drama']           6.7
# 913          2017                     ['Romance', 'Comedy']           6.6
#
#                                                   cast  \
# 909  ['Craig Fairbrass', 'Terry Stone', 'Roland Man...
# 910  ['Michael Greyeyes', 'Elle', 'Máijá Tailfeathe...
# 911  ['Bob Dylan', 'Allen Ginsberg', 'Patti Smith',...
# 912  ['John Huston', 'Oja Kodar', 'Peter Bogdanovic...
# 913  ['Karla Souza', 'José María Yázpik', "Ben O'To...
#
#                        Director  \
# 909               Zackary Adler
# 910                Jeff Barnaby
# 911             Martin Scorsese
# 912                Orson Welles
# 913  Catalina Aguilar Mastretta
#
#                                               keywords  \
# 909                                                 []
# 910                                                 []
# 911                                                 []
# 912  ['film business', 'nudity', 'female nudity', '...
# 913                                                 []
#
#                                                reviews  \
# 909  ["There's a glut of these sort of films but th...
# 910  ["With the lack of a trailer or really any inf...
# 911  ["My ex and I saw Bob Dylan perform in 1984, a...
# 912  ["Years ago I saw a documentary that included ...
# 913  ['This is definitely a light comedy worth reco...
#
#                                       review_sentiment  \
# 909  ['positive', 'positive', 'negative', 'positive...
# 910  ['positive', 'positive', 'negative', 'positive...
# 911  ['positive', 'positive', 'positive', 'positive...
# 912  ['positive', 'positive', 'positive', 'positive...
# 913  ['positive', 'positive', 'negative', 'positive...
#
#                                         review_summary  \
# 909  Audience reaction to Rise of the Footsoldier 3...
# 910  Audience reaction to Blood Quantum is mixed, w...
# 911  Audience reaction to *Rolling Thunder Revue: A...
# 912  The Other Side of the Wind elicits a mixed res...
# 913  "Everybody Loves Somebody" elicits a mixed res...
#
#                                               synopsis  \
# 909  Notorious gangster, Pat Tate, rises through th...
# 910  The dead are coming back to life outside the i...
# 911  In an alchemic mix of fact and fantasy, Martin...
# 912  At a media-swamped party to celebrate his 70th...
# 913  A single, successful career woman asks her co-...
#
#                           poster_path                     backdrop_path
# 909  /1LgOIQNpTfWKY3wizRrQ6CvNAXK.jpg  /vC0x4816uI8yHSLaCzjfdTTSDK1.jpg
# 910  /pQnfrys3nyOpUxktxK2CBnm7Rv8.jpg  /xg1adjc8iEsQ4znJNjUQSvuiPjr.jpg
# 911  /ixxELBgYj9OH8hz0XCrcZOJpIx9.jpg  /4MYtYsSGzQUUYQqHGWBNeEkT91s.jpg
# 912  /kFky1paYEfHxfCYByEc9g7gn6Zk.jpg  /wXUcSJG6dqNKgIRgqYqX98UA1wz.jpg
# 913  /bZKpuVXmYu6gaprjfkOdvlvY5Z9.jpg  /aAeUP99GEhJr2KIHzfA9chqqXUD.jpg

# %% [markdown]
# # Fetching Synopsis from the IMDB Website
# Here, our aim is to fetch the synopsis from the IMDB website for each movie. This will help us in getting the text data for each movie which can be used for further analysis and movie discussion. Now, we have built a web scraper using BeautifulSoup and requests library to fetch the synopsis from the IMDB website, in such a way that we get all the synopsis and summaries as a list, out of which we select with the longest length. In this way, we can get the most detailed synopsis for each movie if it exists, else we can get the longest summary of the movie.

# %%
def load_synopsis(imdb_id):
    try:
        driver = webdriver.Safari()
        url = 'https://www.imdb.com/title/{}/plotsummary/?ref_=tt_stry_pl#synopsis'.format(imdb_id)
        driver.get(url)

        wait = WebDriverWait(driver, 10)

        for _ in range(2):
            wait.until(EC.presence_of_element_located((By.CSS_SELECTOR, 'body')))
            driver.find_element(By.CSS_SELECTOR, 'body').send_keys(Keys.PAGE_DOWN)
            time.sleep(2)
            

        soup = BeautifulSoup(driver.page_source, 'html.parser')
        page_section_sections = soup.findAll('section', class_ = "ipc-page-section ipc-page-section--base")
        if page_section_sections is None:
            driver.quit()
            return ""
        
        texts = []
        for section in page_section_sections:
            for div in section:
                texts.append(div.text)
                
        if texts is None:
            driver.quit()
            return ""
                
        synopsis = ""
        for text in texts:
            if len(text) > len(synopsis):
                synopsis = text
        
        driver.quit()
        return synopsis

    except (TimeoutException, NoSuchElementException) as e:
        print(f"Error scraping synopsis: {e}")
        return ""

# %% [markdown]
# Now, we would also need a function to clean the text data, which will remove all the special characters, numbers, and extra spaces from the text data. This will help us in getting the clean text data, as most of the data is in html format and contains special characters and numbers which are not required for our analysis.

# %%
def remove_html_tag(text):
  # We will create a pattern of html tags (means any content which is encapsulated between HTML tags), and then replace/substitute it with an single space string across the text
  pattern = re.compile('<.*?>')
  return pattern.sub(" ",text)

# %%
database_query_based['synopsis'] = database_query_based['IMDB_ID'].apply(load_synopsis)

# %%
database_query_based["synopsis"] = database_query_based["synopsis"].apply(remove_html_tag)

# %% [markdown]
# Now, we can check if any synopsis is missing for any movie, and if it is missing, we can handle those rows.

# %%
blankRows = 0
for i in database_query_based["synopsis"]:
    if(i == ""):
        blankRows += 1
        
blankRows

# Now, let us find the average length of the synopsis
database_query_based['synopsis_length'] = database_query_based['synopsis'].apply(lambda x: len(x.split()))

# %%
print(f"Average length of synopsis: {database_query_based['synopsis_length'].mean()}")
# Out:
# Average length of synopsis: 714.3238512035011

# %% [markdown]
# As we can see, we have fetched the synopsis for each movie and cleaned the text data, and on an average, we have around 714 words which is a decent start to work with the text data. We can set the columns in the correct order.

# %%
database_query_based = database_query_based.drop(columns = ["synopsis_length"])

# %%
database_query_based = database_query_based.reindex(['id','IMDB_ID', 'title', 'release_year', 'genres', 'vote_average','cast','Director', 'keywords', 'reviews', 'review_sentiment', 'review_summary', 'synopsis','poster_path', 'backdrop_path'], axis=1)

# %% [markdown]
# # Finding the Youtube Trailer Link
# Here, our aim is to fetch the youtube trailers from the TMDB website for each movie. This will help us in getting the video data for each movie which can be used for further analysis and movie discussion, and can be given to the Gemini model to understand the video trailers and aid in movie discussion. This is done simply done via the TMDB API.

# %%
tmdb = TMDb()
tmdb.api_key = TMDB_API_KEY

# %%
def get_youtube_link(movie_id):
  response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}&append_to_response=videos'.format(movie_id,tmdb.api_key))
  
  if response.status_code == 429:
      print("Rate limit exceeded. Waiting...")
      time.sleep(2)
      return get_youtube_link(movie_id)  # Recursively call the function after waiting
  elif response.status_code != 200:
      print(f"Error for ID {movie_id}. Status Code: {response.status_code}")
      return ""
      
  data_json = response.json()
  trailers_keys = []
  if data_json['videos']['results']:
    for video in data_json['videos']['results']:
        if video['type'] == "Trailer":
            trailers_keys.append(video['key'])
    
  time.sleep(0.015)
  
  trailers = []
  for key in trailers_keys:
    trailers.append(f"https://www.youtube.com/watch?v={key}")
  
  return trailers

# %%
database_query_based['youtube_trailers'] = database_query_based['id'].apply(get_youtube_link)

# %% [markdown]
# Let us now preprocess the dataframe to make it ready for the database.

# %%
database_query_based = database_query_based.reindex(['id','IMDB_ID', 'title', 'release_year', 'genres', 'vote_average','cast','Director', 'keywords', 'reviews', 'review_sentiment', 'review_summary', 'synopsis','youtube_trailers','poster_path', 'backdrop_path'], axis=1)

# %%
database_query_based['youtube_trailers'] = database_query_based['youtube_trailers'].apply(lambda x: str(x))

# %% [markdown]
# # Trailer Transcripts from YouTubeTranscriptApi

# %%
database_query_based.head()
# Out:
#        id    IMDB_ID                           title  release_year  \
# 0  283995  tt3896198  Guardians of the Galaxy Vol. 2          2017
# 1  480530  tt6343314                        Creed II          2018
# 2  299536  tt4154756          Avengers: Infinity War          2018
# 3  299534  tt4154796               Avengers: Endgame          2019
# 4  337167  tt4477536              Fifty Shades Freed          2018
#
#                               genres  vote_average  \
# 0  ['Adventure', 'Action', 'Sci-Fi']         7.623
# 1                          ['Drama']         6.990
# 2  ['Adventure', 'Action', 'Sci-Fi']         8.260
# 3  ['Adventure', 'Sci-Fi', 'Action']         8.268
# 4               ['Drama', 'Romance']         6.699
#
#                                                 cast                Director  \
# 0  ['Chris Pratt', 'Zoe Saldaña', 'Dave Bautista'...              James Gunn
# 1  ['Michael B. Jordan', 'Sylvester Stallone', 'T...        Steven Caple Jr.
# 2  ['Robert Downey Jr.', 'Chris Hemsworth', 'Mark...  Anthony RussoJoe Russo
# 3  ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruf...  Anthony RussoJoe Russo
# 4  ['Dakota Johnson', 'Jamie Dornan', 'Eric Johns...             James Foley
#
#                                             keywords  \
# 0  ['demi god', 'alien creature', 'sarcasm', 'cra...
# 1  ['baby', 'training montage', 'sequel', 'boxing...
# 2  ['superhero', 'ensemble cast', 'marvel cinemat...
# 3  ['time travel', 'superhero', 'super villain', ...
# 4  ['sex scene', 'wedding ceremony', 'bondage', '...
#
#                                              reviews  \
# 0  ["Despite being a huge comic book nerd I was n...
# 1  ["This movie is not as good as the first Creed...
# 2  ["Avengers infinity war is an emotional roller...
# 3  ["But its a pretty good film. A bit of a mess ...
# 4  ["The first of the three that is actually emot...
#
#                                     review_sentiment  \
# 0  ['positive', 'positive', 'positive', 'positive...
# 1  ['negative', 'positive', 'positive', 'positive...
# 2  ['positive', 'positive', 'positive', 'positive...
# 3  ['positive', 'positive', 'positive', 'positive...
# 4  ['positive', 'negative', 'negative', 'negative...
#
#                                       review_summary  \
# 0  Guardians of the Galaxy Vol. 2 elicited a gene...
# 1  Creed II elicits a mixed response from audienc...
# 2  Avengers: Infinity War elicits a generally pos...
# 3  Avengers: Endgame elicited a largely positive ...
# 4  The audience reaction to Fifty Shades Freed is...
#
#                                             synopsis  \
# 0  In 1980, Peter's father Ego visited Earth and ...
# 1  Three years after his loss to "Pretty" Ricky C...
# 2  Having acquired the Power Stone from the plane...
# 3  In 2018 Clint Barton, who is under house arres...
# 4  The film opens on the wedding day of Anastasia...
#
#                                     youtube_trailers  \
# 0    ['https://www.youtube.com/watch?v=wUn05hdkhjM']
# 1    ['https://www.youtube.com/watch?v=cPNVNqn4T9I']
# 2  ['https://www.youtube.com/watch?v=QwievZ1Tx-8'...
# 3  ['https://www.youtube.com/watch?v=AMSITikqKiM'...
# 4    ['https://www.youtube.com/watch?v=nJCc5HRPxYA']
#
#                         poster_path                     backdrop_path
# 0  /y4MBh0EjBlMuOzv9axM4qJlmhzz.jpg  /aJn9XeesqsrSLKcHfHP4u5985hn.jpg
# 1  /v3QyboWRoA4O9RbcsqH8tJMe8EB.jpg  /xTYGN1b3XkOtODryXTKgdXLtPMz.jpg
# 2  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 3  /or06FN3Dka5tukK1e9sl16pB3iy.jpg  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 4  /9ZedQHPQVveaIYmDSTazhT3y273.jpg  /9ywA15OAiwjSTvg3cBs9B7kOCBF.jpg

# %%
def extract_trailer_info(youtube_links):
    youtube_links = eval(youtube_links)
    trailers_info = []
    
    for link in youtube_links:
        try:
            video_id = link.split("watch?v=")[1]
            transcript = YouTubeTranscriptApi.get_transcript(video_id)
            transcript_data = []
            for segment in transcript:
                transcript_data.append(
                    {
                        "text": segment["text"],
                        "start": segment["start"],
                        "duration": segment["duration"],
                    }
                )

            trailer_info = {"link": link, "transcript": transcript_data}

            trailers_info.append(trailer_info)

        except Exception as e:
            print(f"Error extracting trailer info for {link}")
            trailer_info = {"link": link, "transcript": []}
            trailers_info.append(trailer_info)
    
    return str(trailers_info)

# %% [markdown]
# We can now go ahead and fetch the transcripts for the trailers from the youtube API. This will help us in getting the text data for each trailer which can be used for further analysis and movie discussion. This is done using the youtube API.

# %%
database_query_based['trailers_info'] = database_query_based['youtube_trailers'].apply(extract_trailer_info)
# Out:
# Error extracting trailer info for https://www.youtube.com/watch?v=AMSITikqKiM
# Error extracting trailer info for https://www.youtube.com/watch?v=Rvr68u6k5sI
# Error extracting trailer info for https://www.youtube.com/watch?v=xlnPHQ3TLX8
# Error extracting trailer info for https://www.youtube.com/watch?v=e_uBTsgRJlk
# Error extracting trailer info for https://www.youtube.com/watch?v=Ue7cNNfjCyc
# Error extracting trailer info for https://www.youtube.com/watch?v=6Vtf0MszgP8
# Error extracting trailer info for https://www.youtube.com/watch?v=geFtxCSz8xI
# Error extracting trailer info for https://www.youtube.com/watch?v=dZOaI_Fn5o4
# Error extracting trailer info for https://www.youtube.com/watch?v=gCcx85zbxz4
# Error extracting trailer info for https://www.youtube.com/watch?v=lCkVr1n1eCA
# Error extracting trailer info for https://www.youtube.com/watch?v=vSKlICmmi98
# Error extracting trailer info for https://www.youtube.com/watch?v=ii3n7hYQOl4
# Error extracting trailer info for https://www.youtube.com/watch?v=LZrX9mffH8Y
# Error extracting trailer info for https://www.youtube.com/watch?v=Sx1Qm3gavRg
# Error extracting trailer info for https://www.youtube.com/watch?v=NooW_RbfdWI
# Error extracting trailer info for https://www.youtube.com/watch?v=OqYyEJpa7xg
# Error extracting trailer info for https://www.youtube.com/watch?v=n6BVyk7hty8
# Error extracting trailer info for https://www.youtube.com/watch?v=rqEnM25BsNQ
# Error extracting trailer info for https://www.youtube.com/watch?v=WR7cc5t7tv8
# Error extracting trailer info for https://www.youtube.com/watch?v=p9wE8dyzEJE
# Error extracting trailer info for https://www.youtube.com/watch?v=5DEdq57E5ls
# Error extracting trailer info for https://www.youtube.com/watch?v=-RFFRxcoKfA
# Error extracting trailer info for https://www.youtube.com/watch?v=MEOOas3JZt0
# Error extracting trailer info for https://www.youtube.com/watch?v=wb49-oV0F78
# Error extracting trailer info for https://www.youtube.com/watch?v=pU8-7BX9uxs
# Error extracting trailer info for https://www.youtube.com/watch?v=M7XM597XO94
# Error extracting trailer info for https://www.youtube.com/watch?v=UvMVjwwZOF4
# Error extracting trailer info for https://www.youtube.com/watch?v=WE13fuVrPjE
# Error extracting trailer info for https://www.youtube.com/watch?v=xKJmEC5ieOk
# Error extracting trailer info for https://www.youtube.com/watch?v=FnCdOQsX5kc
# Error extracting trailer info for https://www.youtube.com/watch?v=-ziu6JzJTZ0
# Error extracting trailer info for https://www.youtube.com/watch?v=mspnr56tnLA
# Error extracting trailer info for https://www.youtube.com/watch?v=8BAhwgjMvnM
# Error extracting trailer info for https://www.youtube.com/watch?v=fUjicxMPDzs
# Error extracting trailer info for https://www.youtube.com/watch?v=0fvqnGmr9S8
# Error extracting trailer info for https://www.youtube.com/watch?v=6Nxc-3WpMbg
# Error extracting trailer info for https://www.youtube.com/watch?v=3Sy7RofBmrs
# Error extracting trailer info for https://www.youtube.com/watch?v=FtSd844cI7U
# Error extracting trailer info for https://www.youtube.com/watch?v=262423505
# Error extracting trailer info for https://www.youtube.com/watch?v=xfSNpHHLrAw
# Error extracting trailer info for https://www.youtube.com/watch?v=npBIzUDnj8c
# Error extracting trailer info for https://www.youtube.com/watch?v=D6Do1p1CWyc
# Error extracting trailer info for https://www.youtube.com/watch?v=Zr86uisFYsI
# Error extracting trailer info for https://www.youtube.com/watch?v=n6ihJIjVGLo
# Error extracting trailer info for https://www.youtube.com/watch?v=Q_iNEXIHzWs
# Error extracting trailer info for https://www.youtube.com/watch?v=zzNNxgp_pmQ
# Error extracting trailer info for https://www.youtube.com/watch?v=xVez1uCdndc
# Error extracting trailer info for https://www.youtube.com/watch?v=g0KBinxAXl4
# Error extracting trailer info for https://www.youtube.com/watch?v=h9nrBkQ2YBo
# Error extracting trailer info for https://www.youtube.com/watch?v=lLfAW8KO6NE
# Error extracting trailer info for https://www.youtube.com/watch?v=nwfXcY55aPg
# Error extracting trailer info for https://www.youtube.com/watch?v=Y6U-eMDmMoc
# Error extracting trailer info for https://www.youtube.com/watch?v=mk0khHCMTYE
# Error extracting trailer info for https://www.youtube.com/watch?v=k86KDFh_q6E
# Error extracting trailer info for https://www.youtube.com/watch?v=Mnj-MXs1yVU
# Error extracting trailer info for https://www.youtube.com/watch?v=YEoRqWMu5fI
# Error extracting trailer info for https://www.youtube.com/watch?v=kB15UFO5ebA
# Error extracting trailer info for https://www.youtube.com/watch?v=2apnlrZmv28
# Error extracting trailer info for https://www.youtube.com/watch?v=_bfqsNh6U7c
# Error extracting trailer info for https://www.youtube.com/watch?v=cFQvVD5y81I
# Error extracting trailer info for https://www.youtube.com/watch?v=81uxmIO_lps
# Error extracting trailer info for https://www.youtube.com/watch?v=LGTMkU7QK5o
# Error extracting trailer info for https://www.youtube.com/watch?v=eth7JUKVwok
# Error extracting trailer info for https://www.youtube.com/watch?v=g3IvVejktJE
# Error extracting trailer info for https://www.youtube.com/watch?v=UdP5e8Vl1bw
# Error extracting trailer info for https://www.youtube.com/watch?v=jzPsLEHImzk
# Error extracting trailer info for https://www.youtube.com/watch?v=nrnuOSiH9Wk
# Error extracting trailer info for https://www.youtube.com/watch?v=nMWHBUTHmf0
# Error extracting trailer info for https://www.youtube.com/watch?v=CQ6p9YQ4PuI
# Error extracting trailer info for https://www.youtube.com/watch?v=Y9pWp4BEh5I

# %%
database_query_based = database_query_based.drop(columns = ["youtube_trailers"])

# %%
database_query_based = database_query_based.reindex(['id','IMDB_ID', 'title', 'release_year', 'genres', 'vote_average','cast','Director', 'keywords', 'reviews', 'review_sentiment', 'review_summary', 'synopsis','trailers_info','poster_path', 'backdrop_path'], axis=1)

# %% [markdown]
# Let us now go ahead and save the final dataframe to the database.

# %%
database = "/Users/dhruv/Desktop/Machine_Learning/Projects/Chitra_Movie_Bot/SQL_Database/Movies.db"
database_query_based.to_sql("Movies_Database", sqlite3.connect(database), if_exists = "replace", index = False)
# Out:
# 914
