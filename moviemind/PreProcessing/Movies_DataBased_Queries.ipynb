# %% [markdown]
# # Importing the dependencies

# %%
import pandas as pd
import numpy as np
import sqlite3

from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %% [markdown]
# # Loading the Database
# We will now load the database and work with some high end language models, and LLMs, to better understand the dataset and pre compute some of the features that we will use in the model.

# %%
# data_query_based = pd.read_csv("../Data/Movies_Query_Based.csv")
# data_query_based.head()

# %%
data_query_based = pd.read_csv("/content/Movies_Query_Based.csv")
data_query_based.head()
# Out:
#        id    IMDB_ID                           title  release_year  \
# 0  283995  tt3896198  Guardians of the Galaxy Vol. 2          2017
# 1  480530  tt6343314                        Creed II          2018
# 2  299536  tt4154756          Avengers: Infinity War          2018
# 3  299534  tt4154796               Avengers: Endgame          2019
# 4  337167  tt4477536              Fifty Shades Freed          2018
#
#                     genres  vote_average            Actor_1  \
# 0  Adventure Action Sci-Fi         7.623        Chris Pratt
# 1                    Drama         6.990  Michael B. Jordan
# 2  Adventure Action Sci-Fi         8.260  Robert Downey Jr.
# 3  Adventure Sci-Fi Action         8.268  Robert Downey Jr.
# 4            Drama Romance         6.699     Dakota Johnson
#
#               Actor_2         Actor_3          Actor_4             Actor_5  \
# 0         Zoe Saldaña   Dave Bautista       Vin Diesel      Bradley Cooper
# 1  Sylvester Stallone  Tessa Thompson      Wood Harris     Russell Hornsby
# 2     Chris Hemsworth    Mark Ruffalo      Chris Evans  Scarlett Johansson
# 3         Chris Evans    Mark Ruffalo  Chris Hemsworth  Scarlett Johansson
# 4        Jamie Dornan    Eric Johnson      Luke Grimes            Rita Ora
#
#                  Director                                           keywords  \
# 0              James Gunn  ['demi god', 'alien creature', 'sarcasm', 'cra...
# 1        Steven Caple Jr.  ['baby', 'training montage', 'sequel', 'boxing...
# 2  Anthony RussoJoe Russo  ['superhero', 'ensemble cast', 'marvel cinemat...
# 3  Anthony RussoJoe Russo  ['time travel', 'superhero', 'super villain', ...
# 4             James Foley  ['sex scene', 'wedding ceremony', 'bondage', '...
#
#                                              reviews  \
# 0  ["Despite being a huge comic book nerd I was n...
# 1  ["This movie is not as good as the first Creed...
# 2  ["Avengers infinity war is an emotional roller...
# 3  ["But its a pretty good film. A bit of a mess ...
# 4  ["The first of the three that is actually emot...
#
#                         poster_path                     backdrop_path
# 0  /y4MBh0EjBlMuOzv9axM4qJlmhzz.jpg  /aJn9XeesqsrSLKcHfHP4u5985hn.jpg
# 1  /v3QyboWRoA4O9RbcsqH8tJMe8EB.jpg  /xTYGN1b3XkOtODryXTKgdXLtPMz.jpg
# 2  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 3  /or06FN3Dka5tukK1e9sl16pB3iy.jpg  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 4  /9ZedQHPQVveaIYmDSTazhT3y273.jpg  /9ywA15OAiwjSTvg3cBs9B7kOCBF.jpg

# %% [markdown]
# # Sentiment Analysis with ROBERTA
# As we have seen in the previous notebook [here](./Sentiment_Model.ipynb), the sentiment analysis done using ROBERTA has proved to be the most efficient to correctly predict the sentiment of the text. We will now use the same model to predict the sentiment of the text in the dataset, and store them as values.

# %%
MOD = f"aychang/roberta-base-imdb"
tokenizer = AutoTokenizer.from_pretrained(MOD)
model = AutoModelForSequenceClassification.from_pretrained(MOD).to("cuda")

# %%
def sentiment_pred_roberta(text):
    encoded_text = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    output = model(**encoded_text)

    scores = output[0][0].detach().numpy()
    
    scores = softmax(scores)

    max_index = np.argmax(scores)

    if max_index == 0:
        sentiment = 'negative'
    elif max_index == 1:
        sentiment = 'positive'

    return sentiment

# %%
list1 = []
for i in eval(data_query_based['reviews'].iloc[0]):
    list1.append(sentiment_pred_roberta(i))

list1
# Out:
# ['positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive',
#  'positive',
#  'positive',
#  'positive',
#  'negative',
#  'positive']
