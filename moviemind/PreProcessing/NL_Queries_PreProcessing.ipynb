# %% [markdown]
# # NL Queries PreProcessing
# Here, we will combine all the data that we have used as a base to fetch all the movies we are working on with necessary features. We aim to use all of them as filters as well as get them ready to be used in as NL (Natural Language) Queries in our application.

# %% [markdown]
# ## Importing the Dependencies

# %%
import pandas as pd
import time
import json
 
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException, NoSuchElementException
from bs4 import BeautifulSoup

# %%
data = pd.read_csv("/Users/dhruv/Desktop/Machine_Learning/Projects/Movie_Recommender/Working/Working_Data/Movies_Final.csv") # This is all the data we used for our model

# %%
data.head()
# Out:
#        id                              title  \
# 0  615656                  Meg 2: The Trench
# 1  758323                The Pope's Exorcist
# 2  667538   Transformers: Rise of the Beasts
# 3  640146  Ant-Man and the Wasp: Quantumania
# 4  677179                          Creed III
#
#                                                 tags     IMDB_ID
# 0  action sci-fi horror jason statham wu jing shu...   tt9224104
# 1  horror mystery thriller russell crowe daniel z...  tt13375076
# 2  action adventure sci-fi anthony ramos dominiqu...   tt5090568
# 3  action adventure sci-fi paul rudd evangeline l...  tt10954600
# 4  drama action michael b. jordan tessa thompson ...  tt11145118

# %% [markdown]
# So from here, let us apply the pre processing techniques we did to make our database more precise.

# %%
data.columns
# Out:
# Index(['id', 'title', 'tags', 'IMDB_ID'], dtype='object')

# %%
data.shape
# Out:
# (26241, 4)

# %%
data2 = pd.read_csv("/Users/dhruv/Desktop/Machine_Learning/Projects/Movie_Recommender/Working/Data/Working_Data/Movie_Data.csv")
data2.head()
# Out:
#        id                              title                   genres  \
# 0  615656                  Meg 2: The Trench     Action Sci-Fi Horror
# 1  758323                The Pope's Exorcist  Horror Mystery Thriller
# 2  667538   Transformers: Rise of the Beasts  Action Adventure Sci-Fi
# 3  640146  Ant-Man and the Wasp: Quantumania  Action Adventure Sci-Fi
# 4  677179                          Creed III             Drama Action
#
#   original_language  release_year  runtime  \
# 0                en          2023    116.0
# 1                en          2023    103.0
# 2                en          2023    127.0
# 3                en          2023    125.0
# 4                en          2023    116.0
#
#                                                 keys            Actor_1  \
# 0      ['based on novel or book', 'sequel', 'kaiju']      Jason Statham
# 1  ['spain', 'rome italy', 'vatican', 'pope', 'pi...      Russell Crowe
# 2  ['peru', 'alien', 'end of the world', 'based o...      Anthony Ramos
# 3  ['hero', 'ant', 'sequel', 'superhero', 'based ...          Paul Rudd
# 4  ['philadelphia pennsylvania', 'husband wife re...  Michael B. Jordan
#
#               Actor_2            Actor_3             Actor_4  \
# 0             Wu Jing   Shuya Sophia Cai        Sergio Peris
# 1      Daniel Zovatto         Alex Essoe         Franco Nero
# 2  Dominique Fishback  Luna Lauren Velez  Dean Scott Vazquez
# 3    Evangeline Lilly    Jonathan Majors      Kathryn Newton
# 4      Tessa Thompson    Jonathan Majors         Wood Harris
#
#              Actor_5           Director
# 0           Mencheta       Ben Wheatley
# 1      Peter DeSouza       Julius Avery
# 2        Tobe Nwigwe   Steven Caple Jr.
# 3  Michelle Pfeiffer        Peyton Reed
# 4    Phylicia Rashād  Michael B. Jordan

# %% [markdown]
# Now, we would go ahead and fetch the year from the second dataset and merge it with the first dataset, so as to ensure we only take the latest movies in the past 5 years.

# %%
data2 = data2[['id', 'release_year']]

# %%
data = pd.merge(data, data2, left_on='id', right_on='id', how='left')
data
# Out:
#            id                              title  \
# 0      615656                  Meg 2: The Trench
# 1      758323                The Pope's Exorcist
# 2      667538   Transformers: Rise of the Beasts
# 3      640146  Ant-Man and the Wasp: Quantumania
# 4      677179                          Creed III
# ...       ...                                ...
# 30530  516266                  Love And Politics
# 30531  514859                         Remarkable
# 30532  527597          In Sickness And In Health
# 30533  527320                    While You Slept
# 30534  554132                     2012 Countdown
#
#                                                     tags     IMDB_ID  \
# 0      action sci-fi horror jason statham wu jing shu...   tt9224104
# 1      horror mystery thriller russell crowe daniel z...  tt13375076
# 2      action adventure sci-fi anthony ramos dominiqu...   tt5090568
# 3      action adventure sci-fi paul rudd evangeline l...  tt10954600
# 4      drama action michael b. jordan tessa thompson ...  tt11145118
# ...                                                  ...         ...
# 30530  drama alex usifo pete edochie ngozi ezeonu unk...         NaN
# 30531  drama daniel k. daniel nita sheu byack tope te...         NaN
# 30532  drama oc ukeje beverly naya meg otanwa rotimi ...         NaN
# 30533  drama ini edo joseph benjamin venita akpofure ...         NaN
# 30534  comedy sci-fi mystery vincent tomas sonja vela...   tt2221088
#
#        release_year
# 0              2023
# 1              2023
# 2              2023
# 3              2023
# 4              2023
# ...             ...
# 30530          2003
# 30531          2017
# 30532          2018
# 30533          2015
# 30534          2012
#
# [30535 rows x 5 columns]

# %% [markdown]
# ## Fetching only the top 1000 movies within the range of 2017 to 2019
# Here, we will only fetch those movies which have been released in the range of 2017 to 2019. This is to ensure that we an ideal amount of movies and are able to train the future models on the same.

# %%
data = data.loc[(data['release_year'] <=2019) & (data['release_year'] >= 2017)]
data = data[0:1000]
data
# Out:
#           id                           title  \
# 38    283995  Guardians of the Galaxy Vol. 2
# 60    480530                        Creed II
# 102   299536          Avengers: Infinity War
# 115   299534               Avengers: Endgame
# 121   337167              Fifty Shades Freed
# ...      ...                             ...
# 5283  661289  The Summers of IT: Chapter Two
# 5284  661289  The Summers of IT: Chapter Two
# 5286  431093        Everybody Loves Somebody
# 5302  602198                      Saving Zoë
# 5308  543412                    Do Not Reply
#
#                                                    tags    IMDB_ID  \
# 38    adventure action sci-fi chris pratt zoe saldañ...  tt3896198
# 60    drama michael b. jordan sylvester stallone tes...  tt6343314
# 102   adventure action sci-fi robert downey jr. chri...  tt4154756
# 115   adventure sci-fi action robert downey jr. chri...  tt4154796
# 121   drama romance dakota johnson jamie dornan eric...  tt4477536
# ...                                                 ...        ...
# 5283  horror drama fantasy andy bean jessica chastai...        NaN
# 5284  horror drama fantasy andy bean jessica chastai...        NaN
# 5286  romance comedy karla souza josé maría yázpik b...  tt5537228
# 5302  drama mystery thriller laura marano vanessa ma...  tt7319822
# 5308  horror thriller jackson rathbone amanda arcuri...  tt8168992
#
#       release_year
# 38            2017
# 60            2018
# 102           2018
# 115           2019
# 121           2018
# ...            ...
# 5283          2019
# 5284          2019
# 5286          2017
# 5302          2019
# 5308          2019
#
# [1000 rows x 5 columns]

# %%
data.isna().sum()
# Out:
# id              0
# title           0
# tags            0
# IMDB_ID         4
# release_year    0
# dtype: int64

# %% [markdown]
# Since we can see there are some movies which have a null IMDB_ID tag, we will remove them from our database.

# %%
data = data.dropna()
data.shape
# Out:
# (996, 5)

# %%
data = data.drop_duplicates(subset='id')

# %%
data
# Out:
#           id                                              title  \
# 38    283995                     Guardians of the Galaxy Vol. 2
# 60    480530                                           Creed II
# 102   299536                             Avengers: Infinity War
# 115   299534                                  Avengers: Endgame
# 121   337167                                 Fifty Shades Freed
# ...      ...                                                ...
# 5269  574638  Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 5281  299782                         The Other Side of the Wind
# 5286  431093                           Everybody Loves Somebody
# 5302  602198                                         Saving Zoë
# 5308  543412                                       Do Not Reply
#
#                                                    tags    IMDB_ID  \
# 38    adventure action sci-fi chris pratt zoe saldañ...  tt3896198
# 60    drama michael b. jordan sylvester stallone tes...  tt6343314
# 102   adventure action sci-fi robert downey jr. chri...  tt4154756
# 115   adventure sci-fi action robert downey jr. chri...  tt4154796
# 121   drama romance dakota johnson jamie dornan eric...  tt4477536
# ...                                                 ...        ...
# 5269  documentary music bob dylan allen ginsberg pat...  tt9577852
# 5281  drama john huston oja kodar peter bogdanovich ...  tt0069049
# 5286  romance comedy karla souza josé maría yázpik b...  tt5537228
# 5302  drama mystery thriller laura marano vanessa ma...  tt7319822
# 5308  horror thriller jackson rathbone amanda arcuri...  tt8168992
#
#       release_year
# 38            2017
# 60            2018
# 102           2018
# 115           2019
# 121           2018
# ...            ...
# 5269          2019
# 5281          2018
# 5286          2017
# 5302          2019
# 5308          2019
#
# [996 rows x 5 columns]

# %% [markdown]
# # Fetching Keywords from the IMDB Website
# Here, our aim is to fetch the top used keywords from the IMDB website for each movie. This will help us in getting the keywords and aid us in performing the recommendation system for the movies, as well as help us in getting the most used keywords for the movies based on which the user can ask the queries based on what type of movie they want to watch.

# %%
def load_keywords(imdb_id):
    try:
        keyword_list = []
        driver = webdriver.Safari()
        url = 'https://www.imdb.com/title/{}/keywords/?ref_=tt_stry_kw'.format(imdb_id)
        driver.get(url)

        wait = WebDriverWait(driver, 10)

        for _ in range(2):
            wait.until(EC.presence_of_element_located((By.CSS_SELECTOR, 'body')))
            driver.find_element(By.CSS_SELECTOR, 'body').send_keys(Keys.PAGE_DOWN)
            time.sleep(1)

        soup = BeautifulSoup(driver.page_source, 'html.parser')
        keywords = soup.find('ul', class_="ipc-metadata-list ipc-metadata-list--dividers-after sc-49ddc26b-0 gXSKic ipc-metadata-list--base")  
        if(keywords == None):
            driver.quit()
            return []
        keywords = keywords.find_all('li')

        for keyword in keywords[:25]:
            keyword_text = keyword.find('div', class_='ipc-metadata-list-summary-item__tc')
            if keyword_text:
                keyword_list.append(keyword_text.text.strip())  # Extract and strip text

        driver.quit()
        return keyword_list

    except (TimeoutException, NoSuchElementException) as e:
        print(f"Error scraping keywords: {e}")
        return []

# %%
imdb_ids = data['IMDB_ID'].tolist()

keywords_list = []
for imdb_id in imdb_ids:
    keywords = load_keywords(imdb_id)
    keywords_list.append(keywords)
    
data['keywords'] = keywords_list
# Out:
# /var/folders/j2/bm5_1y8d2b74tcynr06c6s_c0000gn/T/ipykernel_8929/632349652.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['keywords'] = keywords_list

# %%
data
# Out:
#          id                                              title  \
# 0    283995                     Guardians of the Galaxy Vol. 2
# 1    480530                                           Creed II
# 2    299536                             Avengers: Infinity War
# 3    299534                                  Avengers: Endgame
# 4    337167                                 Fifty Shades Freed
# ..      ...                                                ...
# 991  574638  Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 992  299782                         The Other Side of the Wind
# 993  431093                           Everybody Loves Somebody
# 994  602198                                         Saving Zoë
# 995  543412                                       Do Not Reply
#
#                                                   tags    IMDB_ID  \
# 0    adventure action sci-fi chris pratt zoe saldañ...  tt3896198
# 1    drama michael b. jordan sylvester stallone tes...  tt6343314
# 2    adventure action sci-fi robert downey jr. chri...  tt4154756
# 3    adventure sci-fi action robert downey jr. chri...  tt4154796
# 4    drama romance dakota johnson jamie dornan eric...  tt4477536
# ..                                                 ...        ...
# 991  documentary music bob dylan allen ginsberg pat...  tt9577852
# 992  drama john huston oja kodar peter bogdanovich ...  tt0069049
# 993  romance comedy karla souza josé maría yázpik b...  tt5537228
# 994  drama mystery thriller laura marano vanessa ma...  tt7319822
# 995  horror thriller jackson rathbone amanda arcuri...  tt8168992
#
#      release_year                                           keywords
# 0            2017  ['demi god', 'alien creature', 'sarcasm', 'cra...
# 1            2018  ['baby', 'training montage', 'sequel', 'boxing...
# 2            2018  ['superhero', 'ensemble cast', 'marvel cinemat...
# 3            2019  ['time travel', 'superhero', 'super villain', ...
# 4            2018  ['sex scene', 'wedding ceremony', 'bondage', '...
# ..            ...                                                ...
# 991          2019                                                 []
# 992          2018  ['film business', 'nudity', 'female nudity', '...
# 993          2017                                                 []
# 994          2019                                                 []
# 995          2019  ['abduction', 'abuse', 'held at knifepoint', '...
#
# [996 rows x 6 columns]

# %%
data["keywords"] = data["keywords"].apply(lambda x: eval(x))

# %% [markdown]
# # Fetching Reviews from the IMDB Website
# Here, our aim is to fetch the top 25 reviews from the IMDB website for each movie. This will help us in getting the reviews for the movies and then we can use them to train our model for further sentiment analysis.

# %%
def load_reviews(imdb_id):
    try:
        review_list = []
        driver = webdriver.Safari()
        url = 'https://www.imdb.com/title/{}/reviews?ref_=tt_ov_rt'.format(imdb_id)
        driver.get(url)

        wait = WebDriverWait(driver, 10) 

        for _ in range(2):
            wait.until(EC.presence_of_element_located((By.CSS_SELECTOR, 'body')))
            driver.find_element(By.CSS_SELECTOR, 'body').send_keys(Keys.PAGE_DOWN)
            time.sleep(1)

        soup = BeautifulSoup(driver.page_source, 'html.parser')
        reviews = soup.find_all('div', class_='review-container')
        if(reviews == None):
            driver.quit()
            return []

        for review in reviews[:25]: 
            review_text = review.find('div', class_='text')
            if review_text:
                review_list.append(review_text.get_text(strip=True)) 

        driver.quit()
        return review_list

    except (TimeoutException, NoSuchElementException) as e:
        print(f"Error scraping reviews: {e}")
        return []

# %%
imdb_ids = data['IMDB_ID'].tolist()

reviews_list = []
for imdb_id in imdb_ids:
    reviews = load_reviews(imdb_id)
    reviews_list.append(reviews)
    
data['reviews'] = reviews_list

# %%
data
# Out:
#          id                                              title  \
# 0    283995                     Guardians of the Galaxy Vol. 2
# 1    480530                                           Creed II
# 2    299536                             Avengers: Infinity War
# 3    299534                                  Avengers: Endgame
# 4    337167                                 Fifty Shades Freed
# ..      ...                                                ...
# 991  574638  Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 992  299782                         The Other Side of the Wind
# 993  431093                           Everybody Loves Somebody
# 994  602198                                         Saving Zoë
# 995  543412                                       Do Not Reply
#
#                                                   tags    IMDB_ID  \
# 0    adventure action sci-fi chris pratt zoe saldañ...  tt3896198
# 1    drama michael b. jordan sylvester stallone tes...  tt6343314
# 2    adventure action sci-fi robert downey jr. chri...  tt4154756
# 3    adventure sci-fi action robert downey jr. chri...  tt4154796
# 4    drama romance dakota johnson jamie dornan eric...  tt4477536
# ..                                                 ...        ...
# 991  documentary music bob dylan allen ginsberg pat...  tt9577852
# 992  drama john huston oja kodar peter bogdanovich ...  tt0069049
# 993  romance comedy karla souza josé maría yázpik b...  tt5537228
# 994  drama mystery thriller laura marano vanessa ma...  tt7319822
# 995  horror thriller jackson rathbone amanda arcuri...  tt8168992
#
#      release_year                                           keywords  \
# 0            2017  ['demi god', 'alien creature', 'sarcasm', 'cra...
# 1            2018  ['baby', 'training montage', 'sequel', 'boxing...
# 2            2018  ['superhero', 'ensemble cast', 'marvel cinemat...
# 3            2019  ['time travel', 'superhero', 'super villain', ...
# 4            2018  ['sex scene', 'wedding ceremony', 'bondage', '...
# ..            ...                                                ...
# 991          2019                                                 []
# 992          2018  ['film business', 'nudity', 'female nudity', '...
# 993          2017                                                 []
# 994          2019                                                 []
# 995          2019  ['abduction', 'abuse', 'held at knifepoint', '...
#
#                                                reviews
# 0    [Despite being a huge comic book nerd I was no...
# 1    [This movie is not as good as the first Creed....
# 2    [Avengers infinity war is an emotional roller ...
# 3    [But its a pretty good film. A bit of a mess i...
# 4    [The first of the three that is actually emoti...
# ..                                                 ...
# 991  [My ex and I saw Bob Dylan perform in 1984, a ...
# 992  [Years ago I saw a documentary that included a...
# 993  [This is definitely a light comedy worth recom...
# 994  [This movie takes you on a road to discovery t...
# 995  [It had this creepy dollhouse-like atmosphere....
#
# [996 rows x 7 columns]

# %% [markdown]
# # Integrating Keywords into Tags
# Here, since we have received new keywords from the IMDB website, it would be adivislble to extarct those and also integrate them into the tags of the movies. This will help us in getting the most used keywords for the movies and then we can use them to train our model for further keyword based recommendation system.

# %%
for i in range(0,len(data["tags"])):
    for j in data["keywords"].iloc[i]:
        data["tags"].iloc[i] + j + " "

# %%
data.head()
# Out:
#        id                           title  \
# 0  283995  Guardians of the Galaxy Vol. 2
# 1  480530                        Creed II
# 2  299536          Avengers: Infinity War
# 3  299534               Avengers: Endgame
# 4  337167              Fifty Shades Freed
#
#                                                 tags    IMDB_ID  release_year  \
# 0  adventure action sci-fi chris pratt zoe saldañ...  tt3896198          2017
# 1  drama michael b. jordan sylvester stallone tes...  tt6343314          2018
# 2  adventure action sci-fi robert downey jr. chri...  tt4154756          2018
# 3  adventure sci-fi action robert downey jr. chri...  tt4154796          2019
# 4  drama romance dakota johnson jamie dornan eric...  tt4477536          2018
#
#                                             keywords  \
# 0  [demi god, alien creature, sarcasm, crash land...
# 1  [baby, training montage, sequel, boxing match,...
# 2  [superhero, ensemble cast, marvel cinematic un...
# 3  [time travel, superhero, super villain, cosmic...
# 4  [sex scene, wedding ceremony, bondage, car cha...
#
#                                              reviews
# 0  [Despite being a huge comic book nerd I was no...
# 1  [This movie is not as good as the first Creed....
# 2  [Avengers infinity war is an emotional roller ...
# 3  [But its a pretty good film. A bit of a mess i...
# 4  [The first of the three that is actually emoti...

# %% [markdown]
# # Merging other columns with the main dataset
# Here, we will merge the other columns with the main dataset and then we will be able to use them as filters in our application, along with creating the database for them, which can be accessed in case of any data based queries from the user.|

# %%
data2 = pd.read_csv("/Users/dhruv/Desktop/Machine_Learning/Projects/Movie_Recommender/Working/Data/Working_Data/Movie_Data.csv")
data2.head()
# Out:
#        id                              title                   genres  \
# 0  615656                  Meg 2: The Trench     Action Sci-Fi Horror
# 1  758323                The Pope's Exorcist  Horror Mystery Thriller
# 2  667538   Transformers: Rise of the Beasts  Action Adventure Sci-Fi
# 3  640146  Ant-Man and the Wasp: Quantumania  Action Adventure Sci-Fi
# 4  677179                          Creed III             Drama Action
#
#   original_language  release_year  runtime  \
# 0                en          2023    116.0
# 1                en          2023    103.0
# 2                en          2023    127.0
# 3                en          2023    125.0
# 4                en          2023    116.0
#
#                                                 keys            Actor_1  \
# 0      ['based on novel or book', 'sequel', 'kaiju']      Jason Statham
# 1  ['spain', 'rome italy', 'vatican', 'pope', 'pi...      Russell Crowe
# 2  ['peru', 'alien', 'end of the world', 'based o...      Anthony Ramos
# 3  ['hero', 'ant', 'sequel', 'superhero', 'based ...          Paul Rudd
# 4  ['philadelphia pennsylvania', 'husband wife re...  Michael B. Jordan
#
#               Actor_2            Actor_3             Actor_4  \
# 0             Wu Jing   Shuya Sophia Cai        Sergio Peris
# 1      Daniel Zovatto         Alex Essoe         Franco Nero
# 2  Dominique Fishback  Luna Lauren Velez  Dean Scott Vazquez
# 3    Evangeline Lilly    Jonathan Majors      Kathryn Newton
# 4      Tessa Thompson    Jonathan Majors         Wood Harris
#
#              Actor_5           Director
# 0           Mencheta       Ben Wheatley
# 1      Peter DeSouza       Julius Avery
# 2        Tobe Nwigwe   Steven Caple Jr.
# 3  Michelle Pfeiffer        Peyton Reed
# 4    Phylicia Rashād  Michael B. Jordan

# %%
data2 = data2[['id', 'genres', 'Actor_1', 'Actor_2', 'Actor_3','Actor_4','Actor_5', 'Director']]
data2.head()
# Out:
#        id                   genres            Actor_1             Actor_2  \
# 0  615656     Action Sci-Fi Horror      Jason Statham             Wu Jing
# 1  758323  Horror Mystery Thriller      Russell Crowe      Daniel Zovatto
# 2  667538  Action Adventure Sci-Fi      Anthony Ramos  Dominique Fishback
# 3  640146  Action Adventure Sci-Fi          Paul Rudd    Evangeline Lilly
# 4  677179             Drama Action  Michael B. Jordan      Tessa Thompson
#
#              Actor_3             Actor_4            Actor_5           Director
# 0   Shuya Sophia Cai        Sergio Peris           Mencheta       Ben Wheatley
# 1         Alex Essoe         Franco Nero      Peter DeSouza       Julius Avery
# 2  Luna Lauren Velez  Dean Scott Vazquez        Tobe Nwigwe   Steven Caple Jr.
# 3    Jonathan Majors      Kathryn Newton  Michelle Pfeiffer        Peyton Reed
# 4    Jonathan Majors         Wood Harris    Phylicia Rashād  Michael B. Jordan

# %%
data = pd.merge(data, data2, left_on='id', right_on='id', how='left')
data.head()
# Out:
#        id                           title  \
# 0  283995  Guardians of the Galaxy Vol. 2
# 1  480530                        Creed II
# 2  299536          Avengers: Infinity War
# 3  299534               Avengers: Endgame
# 4  337167              Fifty Shades Freed
#
#                                                 tags    IMDB_ID  release_year  \
# 0  adventure action sci-fi chris pratt zoe saldañ...  tt3896198          2017
# 1  drama michael b. jordan sylvester stallone tes...  tt6343314          2018
# 2  adventure action sci-fi robert downey jr. chri...  tt4154756          2018
# 3  adventure sci-fi action robert downey jr. chri...  tt4154796          2019
# 4  drama romance dakota johnson jamie dornan eric...  tt4477536          2018
#
#                                             keywords  \
# 0  [demi god, alien creature, sarcasm, crash land...
# 1  [baby, training montage, sequel, boxing match,...
# 2  [superhero, ensemble cast, marvel cinematic un...
# 3  [time travel, superhero, super villain, cosmic...
# 4  [sex scene, wedding ceremony, bondage, car cha...
#
#                                              reviews                   genres  \
# 0  [Despite being a huge comic book nerd I was no...  Adventure Action Sci-Fi
# 1  [This movie is not as good as the first Creed....                    Drama
# 2  [Avengers infinity war is an emotional roller ...  Adventure Action Sci-Fi
# 3  [But its a pretty good film. A bit of a mess i...  Adventure Sci-Fi Action
# 4  [The first of the three that is actually emoti...            Drama Romance
#
#              Actor_1             Actor_2         Actor_3          Actor_4  \
# 0        Chris Pratt         Zoe Saldaña   Dave Bautista       Vin Diesel
# 1  Michael B. Jordan  Sylvester Stallone  Tessa Thompson      Wood Harris
# 2  Robert Downey Jr.     Chris Hemsworth    Mark Ruffalo      Chris Evans
# 3  Robert Downey Jr.         Chris Evans    Mark Ruffalo  Chris Hemsworth
# 4     Dakota Johnson        Jamie Dornan    Eric Johnson      Luke Grimes
#
#               Actor_5                Director
# 0      Bradley Cooper              James Gunn
# 1     Russell Hornsby        Steven Caple Jr.
# 2  Scarlett Johansson  Anthony RussoJoe Russo
# 3  Scarlett Johansson  Anthony RussoJoe Russo
# 4            Rita Ora             James Foley

# %% [markdown]
# We can probaly restructure the columns in our dataset.

# %%
data.columns
# Out:
# Index(['id', 'title', 'tags', 'IMDB_ID', 'release_year', 'keywords', 'reviews',
#        'genres', 'Actor_1', 'Actor_2', 'Actor_3', 'Actor_4', 'Actor_5',
#        'Director'],
#       dtype='object')

# %%
data = data.reindex(columns=['id','IMDB_ID', 'title','release_year' ,'genres', 'Actor_1', 'Actor_2', 'Actor_3', 'Actor_4', 'Actor_5', 'Director', 'keywords', 'reviews','tags'])
data.head()
# Out:
#        id    IMDB_ID                           title  release_year  \
# 0  283995  tt3896198  Guardians of the Galaxy Vol. 2          2017
# 1  480530  tt6343314                        Creed II          2018
# 2  299536  tt4154756          Avengers: Infinity War          2018
# 3  299534  tt4154796               Avengers: Endgame          2019
# 4  337167  tt4477536              Fifty Shades Freed          2018
#
#                     genres            Actor_1             Actor_2  \
# 0  Adventure Action Sci-Fi        Chris Pratt         Zoe Saldaña
# 1                    Drama  Michael B. Jordan  Sylvester Stallone
# 2  Adventure Action Sci-Fi  Robert Downey Jr.     Chris Hemsworth
# 3  Adventure Sci-Fi Action  Robert Downey Jr.         Chris Evans
# 4            Drama Romance     Dakota Johnson        Jamie Dornan
#
#           Actor_3          Actor_4             Actor_5  \
# 0   Dave Bautista       Vin Diesel      Bradley Cooper
# 1  Tessa Thompson      Wood Harris     Russell Hornsby
# 2    Mark Ruffalo      Chris Evans  Scarlett Johansson
# 3    Mark Ruffalo  Chris Hemsworth  Scarlett Johansson
# 4    Eric Johnson      Luke Grimes            Rita Ora
#
#                  Director                                           keywords  \
# 0              James Gunn  [demi god, alien creature, sarcasm, crash land...
# 1        Steven Caple Jr.  [baby, training montage, sequel, boxing match,...
# 2  Anthony RussoJoe Russo  [superhero, ensemble cast, marvel cinematic un...
# 3  Anthony RussoJoe Russo  [time travel, superhero, super villain, cosmic...
# 4             James Foley  [sex scene, wedding ceremony, bondage, car cha...
#
#                                              reviews  \
# 0  [Despite being a huge comic book nerd I was no...
# 1  [This movie is not as good as the first Creed....
# 2  [Avengers infinity war is an emotional roller ...
# 3  [But its a pretty good film. A bit of a mess i...
# 4  [The first of the three that is actually emoti...
#
#                                                 tags
# 0  adventure action sci-fi chris pratt zoe saldañ...
# 1  drama michael b. jordan sylvester stallone tes...
# 2  adventure action sci-fi robert downey jr. chri...
# 3  adventure sci-fi action robert downey jr. chri...
# 4  drama romance dakota johnson jamie dornan eric...

# %% [markdown]
# Now, let us import the final dataset to create the database for the same.

# %%
data3 = pd.read_csv("./Working/Data/TMDB_Movies_Dataset/movies.csv")
data3.head()
# Out:
#        id                              title  \
# 0  615656                  Meg 2: The Trench
# 1  758323                The Pope's Exorcist
# 2  667538   Transformers: Rise of the Beasts
# 3  640146  Ant-Man and the Wasp: Quantumania
# 4  677179                          Creed III
#
#                              genres original_language  \
# 0     Action-Science Fiction-Horror                en
# 1           Horror-Mystery-Thriller                en
# 2  Action-Adventure-Science Fiction                en
# 3  Action-Adventure-Science Fiction                en
# 4                      Drama-Action                en
#
#                                             overview  popularity  \
# 0  An exploratory dive into the deepest depths of...    8763.998
# 1  Father Gabriele Amorth Chief Exorcist of the V...    5953.227
# 2  When a new threat capable of destroying the en...    5409.104
# 3  Super-Hero partners Scott Lang and Hope van Dy...    4425.387
# 4  After dominating the boxing world Adonis Creed...    3994.342
#
#                                 production_companies release_date  \
# 0  Apelles Entertainment-Warner Bros. Pictures-di...   2023-08-02
# 1  Screen Gems-2.0 Entertainment-Jesus & Mary-Wor...   2023-04-05
# 2  Skydance-Paramount-di Bonaventura Pictures-Bay...   2023-06-06
# 3             Marvel Studios-Kevin Feige Productions   2023-02-15
# 4  Metro-Goldwyn-Mayer-Proximity Media-Balboa Pro...   2023-03-01
#
#         budget      revenue  runtime    status  \
# 0  129000000.0  352056482.0    116.0  Released
# 1   18000000.0   65675816.0    103.0  Released
# 2  200000000.0  407045464.0    127.0  Released
# 3  200000000.0  475766228.0    125.0  Released
# 4   75000000.0  269000000.0    116.0  Released
#
#                                              tagline  vote_average  \
# 0                                  Back for seconds.         7.079
# 1  Inspired by the actual files of Father Gabriel...         7.433
# 2                                     Unite or fall.         7.340
# 3            Witness the beginning of a new dynasty.         6.507
# 4                      You can't run from your past.         7.262
#
#    vote_count                                            credits  \
# 0      1365.0  Jason Statham-Wu Jing-Shuya Sophia Cai-Sergio ...
# 1       545.0  Russell Crowe-Daniel Zovatto-Alex Essoe-Franco...
# 2      1007.0  Anthony Ramos-Dominique Fishback-Luna Lauren V...
# 3      2811.0  Paul Rudd-Evangeline Lilly-Jonathan Majors-Kat...
# 4      1129.0  Michael B. Jordan-Tessa Thompson-Jonathan Majo...
#
#                                             keywords  \
# 0                based on novel or book-sequel-kaiju
# 1  spain-rome italy-vatican-pope-pig-possession-c...
# 2  peru-alien-end of the world-based on cartoon-b...
# 3  hero-ant-sequel-superhero-based on comic-famil...
# 4  philadelphia pennsylvania-husband wife relatio...
#
#                         poster_path                     backdrop_path  \
# 0  /4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg  /qlxy8yo5bcgUw2KAmmojUKp4rHd.jpg
# 1  /9JBEPLTPSm0d1mbEcLxULjJq9Eh.jpg  /hiHGRbyTcbZoLsYYkO4QiCLYe34.jpg
# 2  /gPbM0MK8CP8A174rmUwGsADNYKD.jpg  /woJbg7ZqidhpvqFGGMRhWQNoxwa.jpg
# 3  /qnqGbB22YJ7dSs4o6M7exTpNxPz.jpg  /m8JTwHFwX7I7JY5fPe4SjqejWag.jpg
# 4  /cvsXj3I9Q2iyyIo95AecSd1tad7.jpg  /5i6SjyDbDWqyun8klUuCxrlFbyw.jpg
#
#                                      recommendations
# 0  1006462-298618-569094-1061181-346698-1076487-6...
# 1  713704-296271-502356-1076605-1084225-1008005-9...
# 2  496450-569094-298618-385687-877100-598331-4628...
# 3  823999-676841-868759-734048-267805-965839-1033...
# 4  965839-267805-943822-842942-1035806-823999-107...

# %% [markdown]
# From this initial dataset, we only need some basic columns which we can use for presenting a movie, which are poster path, backdrop path and vote average.

# %%
data3 = data3[['id', 'vote_average','poster_path','backdrop_path']]
data3.head()
# Out:
#        id  vote_average                       poster_path  \
# 0  615656         7.079  /4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg
# 1  758323         7.433  /9JBEPLTPSm0d1mbEcLxULjJq9Eh.jpg
# 2  667538         7.340  /gPbM0MK8CP8A174rmUwGsADNYKD.jpg
# 3  640146         6.507  /qnqGbB22YJ7dSs4o6M7exTpNxPz.jpg
# 4  677179         7.262  /cvsXj3I9Q2iyyIo95AecSd1tad7.jpg
#
#                       backdrop_path
# 0  /qlxy8yo5bcgUw2KAmmojUKp4rHd.jpg
# 1  /hiHGRbyTcbZoLsYYkO4QiCLYe34.jpg
# 2  /woJbg7ZqidhpvqFGGMRhWQNoxwa.jpg
# 3  /m8JTwHFwX7I7JY5fPe4SjqejWag.jpg
# 4  /5i6SjyDbDWqyun8klUuCxrlFbyw.jpg

# %%
data = pd.merge(data, data3, left_on='id', right_on='id', how='left')
data.head()
# Out:
#        id    IMDB_ID                           title  release_year  \
# 0  283995  tt3896198  Guardians of the Galaxy Vol. 2          2017
# 1  480530  tt6343314                        Creed II          2018
# 2  299536  tt4154756          Avengers: Infinity War          2018
# 3  299534  tt4154796               Avengers: Endgame          2019
# 4  337167  tt4477536              Fifty Shades Freed          2018
#
#                     genres            Actor_1             Actor_2  \
# 0  Adventure Action Sci-Fi        Chris Pratt         Zoe Saldaña
# 1                    Drama  Michael B. Jordan  Sylvester Stallone
# 2  Adventure Action Sci-Fi  Robert Downey Jr.     Chris Hemsworth
# 3  Adventure Sci-Fi Action  Robert Downey Jr.         Chris Evans
# 4            Drama Romance     Dakota Johnson        Jamie Dornan
#
#           Actor_3          Actor_4             Actor_5  \
# 0   Dave Bautista       Vin Diesel      Bradley Cooper
# 1  Tessa Thompson      Wood Harris     Russell Hornsby
# 2    Mark Ruffalo      Chris Evans  Scarlett Johansson
# 3    Mark Ruffalo  Chris Hemsworth  Scarlett Johansson
# 4    Eric Johnson      Luke Grimes            Rita Ora
#
#                  Director                                           keywords  \
# 0              James Gunn  ['demi god', 'alien creature', 'sarcasm', 'cra...
# 1        Steven Caple Jr.  ['baby', 'training montage', 'sequel', 'boxing...
# 2  Anthony RussoJoe Russo  ['superhero', 'ensemble cast', 'marvel cinemat...
# 3  Anthony RussoJoe Russo  ['time travel', 'superhero', 'super villain', ...
# 4             James Foley  ['sex scene', 'wedding ceremony', 'bondage', '...
#
#                                              reviews  \
# 0  ["Despite being a huge comic book nerd I was n...
# 1  ["This movie is not as good as the first Creed...
# 2  ["Avengers infinity war is an emotional roller...
# 3  ["But its a pretty good film. A bit of a mess ...
# 4  ["The first of the three that is actually emot...
#
#                                                 tags  vote_average  \
# 0  adventure action sci-fi chris pratt zoe saldañ...         7.623
# 1  drama michael b. jordan sylvester stallone tes...         6.990
# 2  adventure action sci-fi robert downey jr. chri...         8.260
# 3  adventure sci-fi action robert downey jr. chri...         8.268
# 4  drama romance dakota johnson jamie dornan eric...         6.699
#
#                         poster_path                     backdrop_path
# 0  /y4MBh0EjBlMuOzv9axM4qJlmhzz.jpg  /aJn9XeesqsrSLKcHfHP4u5985hn.jpg
# 1  /v3QyboWRoA4O9RbcsqH8tJMe8EB.jpg  /xTYGN1b3XkOtODryXTKgdXLtPMz.jpg
# 2  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 3  /or06FN3Dka5tukK1e9sl16pB3iy.jpg  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 4  /9ZedQHPQVveaIYmDSTazhT3y273.jpg  /9ywA15OAiwjSTvg3cBs9B7kOCBF.jpg

# %%
data = data.reindex(columns=['id','IMDB_ID', 'title','release_year' ,'genres','vote_average', 'Actor_1', 'Actor_2', 'Actor_3', 'Actor_4', 'Actor_5', 'Director', 'keywords', 'reviews','poster_path','backdrop_path','tags'])
data.head()
# Out:
#        id    IMDB_ID                           title  release_year  \
# 0  283995  tt3896198  Guardians of the Galaxy Vol. 2          2017
# 1  480530  tt6343314                        Creed II          2018
# 2  299536  tt4154756          Avengers: Infinity War          2018
# 3  299534  tt4154796               Avengers: Endgame          2019
# 4  337167  tt4477536              Fifty Shades Freed          2018
#
#                     genres  vote_average            Actor_1  \
# 0  Adventure Action Sci-Fi         7.623        Chris Pratt
# 1                    Drama         6.990  Michael B. Jordan
# 2  Adventure Action Sci-Fi         8.260  Robert Downey Jr.
# 3  Adventure Sci-Fi Action         8.268  Robert Downey Jr.
# 4            Drama Romance         6.699     Dakota Johnson
#
#               Actor_2         Actor_3          Actor_4             Actor_5  \
# 0         Zoe Saldaña   Dave Bautista       Vin Diesel      Bradley Cooper
# 1  Sylvester Stallone  Tessa Thompson      Wood Harris     Russell Hornsby
# 2     Chris Hemsworth    Mark Ruffalo      Chris Evans  Scarlett Johansson
# 3         Chris Evans    Mark Ruffalo  Chris Hemsworth  Scarlett Johansson
# 4        Jamie Dornan    Eric Johnson      Luke Grimes            Rita Ora
#
#                  Director                                           keywords  \
# 0              James Gunn  ['demi god', 'alien creature', 'sarcasm', 'cra...
# 1        Steven Caple Jr.  ['baby', 'training montage', 'sequel', 'boxing...
# 2  Anthony RussoJoe Russo  ['superhero', 'ensemble cast', 'marvel cinemat...
# 3  Anthony RussoJoe Russo  ['time travel', 'superhero', 'super villain', ...
# 4             James Foley  ['sex scene', 'wedding ceremony', 'bondage', '...
#
#                                              reviews  \
# 0  ["Despite being a huge comic book nerd I was n...
# 1  ["This movie is not as good as the first Creed...
# 2  ["Avengers infinity war is an emotional roller...
# 3  ["But its a pretty good film. A bit of a mess ...
# 4  ["The first of the three that is actually emot...
#
#                         poster_path                     backdrop_path  \
# 0  /y4MBh0EjBlMuOzv9axM4qJlmhzz.jpg  /aJn9XeesqsrSLKcHfHP4u5985hn.jpg
# 1  /v3QyboWRoA4O9RbcsqH8tJMe8EB.jpg  /xTYGN1b3XkOtODryXTKgdXLtPMz.jpg
# 2  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 3  /or06FN3Dka5tukK1e9sl16pB3iy.jpg  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 4  /9ZedQHPQVveaIYmDSTazhT3y273.jpg  /9ywA15OAiwjSTvg3cBs9B7kOCBF.jpg
#
#                                                 tags
# 0  adventure action sci-fi chris pratt zoe saldañ...
# 1  drama michael b. jordan sylvester stallone tes...
# 2  adventure action sci-fi robert downey jr. chri...
# 3  adventure sci-fi action robert downey jr. chri...
# 4  drama romance dakota johnson jamie dornan eric...

# %% [markdown]
# With this, we have our final dataset ready to be used in our application. We will now be splitting this into two portions respecitvely, one for the key based searching query by the user, which we will proceed to store in CHROMADB and the other for the data based query, which we will proceed to store in a regular relational database.

# %%
data_key_based = data[['id','title','tags']]
data_query_based = data.drop(columns=['tags'])

# %%
data_key_based.head()
# Out:
#        id                           title  \
# 0  283995  Guardians of the Galaxy Vol. 2
# 1  480530                        Creed II
# 2  299536          Avengers: Infinity War
# 3  299534               Avengers: Endgame
# 4  337167              Fifty Shades Freed
#
#                                                 tags
# 0  adventure action sci-fi chris pratt zoe saldañ...
# 1  drama michael b. jordan sylvester stallone tes...
# 2  adventure action sci-fi robert downey jr. chri...
# 3  adventure sci-fi action robert downey jr. chri...
# 4  drama romance dakota johnson jamie dornan eric...

# %%
data_query_based.head()
# Out:
#        id    IMDB_ID                           title  release_year  \
# 0  283995  tt3896198  Guardians of the Galaxy Vol. 2          2017
# 1  480530  tt6343314                        Creed II          2018
# 2  299536  tt4154756          Avengers: Infinity War          2018
# 3  299534  tt4154796               Avengers: Endgame          2019
# 4  337167  tt4477536              Fifty Shades Freed          2018
#
#                     genres  vote_average            Actor_1  \
# 0  Adventure Action Sci-Fi         7.623        Chris Pratt
# 1                    Drama         6.990  Michael B. Jordan
# 2  Adventure Action Sci-Fi         8.260  Robert Downey Jr.
# 3  Adventure Sci-Fi Action         8.268  Robert Downey Jr.
# 4            Drama Romance         6.699     Dakota Johnson
#
#               Actor_2         Actor_3          Actor_4             Actor_5  \
# 0         Zoe Saldaña   Dave Bautista       Vin Diesel      Bradley Cooper
# 1  Sylvester Stallone  Tessa Thompson      Wood Harris     Russell Hornsby
# 2     Chris Hemsworth    Mark Ruffalo      Chris Evans  Scarlett Johansson
# 3         Chris Evans    Mark Ruffalo  Chris Hemsworth  Scarlett Johansson
# 4        Jamie Dornan    Eric Johnson      Luke Grimes            Rita Ora
#
#                  Director                                           keywords  \
# 0              James Gunn  ['demi god', 'alien creature', 'sarcasm', 'cra...
# 1        Steven Caple Jr.  ['baby', 'training montage', 'sequel', 'boxing...
# 2  Anthony RussoJoe Russo  ['superhero', 'ensemble cast', 'marvel cinemat...
# 3  Anthony RussoJoe Russo  ['time travel', 'superhero', 'super villain', ...
# 4             James Foley  ['sex scene', 'wedding ceremony', 'bondage', '...
#
#                                              reviews  \
# 0  ["Despite being a huge comic book nerd I was n...
# 1  ["This movie is not as good as the first Creed...
# 2  ["Avengers infinity war is an emotional roller...
# 3  ["But its a pretty good film. A bit of a mess ...
# 4  ["The first of the three that is actually emot...
#
#                         poster_path                     backdrop_path
# 0  /y4MBh0EjBlMuOzv9axM4qJlmhzz.jpg  /aJn9XeesqsrSLKcHfHP4u5985hn.jpg
# 1  /v3QyboWRoA4O9RbcsqH8tJMe8EB.jpg  /xTYGN1b3XkOtODryXTKgdXLtPMz.jpg
# 2  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 3  /or06FN3Dka5tukK1e9sl16pB3iy.jpg  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 4  /9ZedQHPQVveaIYmDSTazhT3y273.jpg  /9ywA15OAiwjSTvg3cBs9B7kOCBF.jpg

# %%
data_key_based.drop_duplicates(subset='id', inplace=True)
data_query_based.drop_duplicates(subset='id', inplace=True)
# Out:
# /var/folders/j2/bm5_1y8d2b74tcynr06c6s_c0000gn/T/ipykernel_57277/3049147002.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_key_based.drop_duplicates(subset='id', inplace=True)

# %%
data_key_based.to_csv("../Data/Movies_Key_Based.csv", index=False)

# %%
data_query_based.to_csv("../Data/Movies_Query_Based.csv", index=False)

# %%
data_query_based.head()
# Out:
#        id    IMDB_ID                           title  release_year  \
# 0  283995  tt3896198  Guardians of the Galaxy Vol. 2          2017
# 1  480530  tt6343314                        Creed II          2018
# 2  299536  tt4154756          Avengers: Infinity War          2018
# 3  299534  tt4154796               Avengers: Endgame          2019
# 4  337167  tt4477536              Fifty Shades Freed          2018
#
#                     genres  vote_average            Actor_1  \
# 0  Adventure Action Sci-Fi         7.623        Chris Pratt
# 1                    Drama         6.990  Michael B. Jordan
# 2  Adventure Action Sci-Fi         8.260  Robert Downey Jr.
# 3  Adventure Sci-Fi Action         8.268  Robert Downey Jr.
# 4            Drama Romance         6.699     Dakota Johnson
#
#               Actor_2         Actor_3          Actor_4             Actor_5  \
# 0         Zoe Saldaña   Dave Bautista       Vin Diesel      Bradley Cooper
# 1  Sylvester Stallone  Tessa Thompson      Wood Harris     Russell Hornsby
# 2     Chris Hemsworth    Mark Ruffalo      Chris Evans  Scarlett Johansson
# 3         Chris Evans    Mark Ruffalo  Chris Hemsworth  Scarlett Johansson
# 4        Jamie Dornan    Eric Johnson      Luke Grimes            Rita Ora
#
#                  Director                                           keywords  \
# 0              James Gunn  ['demi god', 'alien creature', 'sarcasm', 'cra...
# 1        Steven Caple Jr.  ['baby', 'training montage', 'sequel', 'boxing...
# 2  Anthony RussoJoe Russo  ['superhero', 'ensemble cast', 'marvel cinemat...
# 3  Anthony RussoJoe Russo  ['time travel', 'superhero', 'super villain', ...
# 4             James Foley  ['sex scene', 'wedding ceremony', 'bondage', '...
#
#                                              reviews  \
# 0  ["Despite being a huge comic book nerd I was n...
# 1  ["This movie is not as good as the first Creed...
# 2  ["Avengers infinity war is an emotional roller...
# 3  ["But its a pretty good film. A bit of a mess ...
# 4  ["The first of the three that is actually emot...
#
#                         poster_path                     backdrop_path
# 0  /y4MBh0EjBlMuOzv9axM4qJlmhzz.jpg  /aJn9XeesqsrSLKcHfHP4u5985hn.jpg
# 1  /v3QyboWRoA4O9RbcsqH8tJMe8EB.jpg  /xTYGN1b3XkOtODryXTKgdXLtPMz.jpg
# 2  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 3  /or06FN3Dka5tukK1e9sl16pB3iy.jpg  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 4  /9ZedQHPQVveaIYmDSTazhT3y273.jpg  /9ywA15OAiwjSTvg3cBs9B7kOCBF.jpg

# %% [markdown]
# # After this, we will work on showing how to integrate text to SQL here and then we will proceed to show how to use the same in our application, with understanding the different types of data based queries which can be given by the user.

# %% [markdown]
# # Query Processor
# We will aim to understand the type of queries a user might enter on the website and train our model accordingly.

# %% [markdown]
# ### 1. Understand Query Types:
#
# Identify and understand the types of queries you want your system to support. For instance:
# - "Movies directed by Christopher Nolan"
# - "Horror films released in 2010"
# - "Romantic movies starring Julia Roberts"
#
# ### 2. Design a Query Processor:
#
# Given the types of queries you wish to support, design a function that processes these queries. This involves:
# - Tokenizing the query
# - Identifying keywords or named entities like director names, actor names, genres, years, etc.
# - Mapping the identified keywords to relevant columns in your dataset
#
# For a college project:
#
# Start with a Rule-Based Approach: This gives you a working baseline quickly. Implement basic patterns that you anticipate users will employ.
# Integrate NER: This will allow you to flexibly identify movie names, director names, etc. without hardcoding anything.
# Experiment with Pre-trained Models (if feasible): If you're interested in diving deeper and have the computational resources, consider experimenting with fine-tuning a model for query classification or entity recognition.
# Lastly, remember to build iteratively. Get a basic version working, test it, and then incrementally add complexity.

# %%
data.head(2)
# Out:
#        id                      title                       genres  \
# 0  615656   [meg, 2, :, the, trench]     [action, sci-fi, horror]
# 1  758323  [the, pope, 's, exorcist]  [horror, mystery, thriller]
#
#   original_language  release_year  runtime  \
# 0              [en]          2023    116.0
# 1              [en]          2023    103.0
#
#                                                 keys           Actor_1  \
# 0        [based, on, novel, or, book, sequel, kaiju]  [jason, statham]
# 1  [spain, rome, italy, vatican, pope, pig, posse...  [russell, crowe]
#
#              Actor_2               Actor_3          Actor_4           Actor_5  \
# 0         [wu, jing]  [shuya, sophia, cai]  [sergio, peris]        [mencheta]
# 1  [daniel, zovatto]         [alex, essoe]   [franco, nero]  [peter, desouza]
#
#           Director
# 0  [ben, wheatley]
# 1  [julius, avery]

# %% [markdown]
# #### Type of Possible Queries
# For the sake of a rule based approach, we will be taking queries based on the following filters.
#
# * Director Based Queries
#     * Movies directed by Christopher Nolan
#     * What films has Christopher Nolan directed?
# * Actor Based Movies
#     * Films with Leonardo Dicaprio
#     * Movies starting Micheal B Jordan
# * Genre Based Movies
#     * Action Movies from the 2010s
#     * Horror Movies
# * Year Based Movies
#     * Movies from 2015 to 2017
#     * Films released in 2023
# * Keyword Based Movies
#     * Movies about space and science
#     * Superhero films
#     * Romantic feel good movies
#
# Apart from this, we can also have a cominnation of these type of queries. Let us now use a tokenizer to understand and filter our these queries.

# %% [markdown]
# ### 3. Query Execution:
#
# Using the processed query, search your dataset to return relevant results. This can be done using:
# - Exact matches: For queries like director names, years, etc.
# - Fuzzy matching: If you want to handle slight variations or typos in the query
# - Vector representations (like TF-IDF, Word2Vec, etc.): For more complex queries
#
# ### 4. Testing:
#
# Write test cases for your query system to ensure it's working as expected. Start with basic queries and then move on to more complex ones. Iterate and improve your query processor based on the results.
#
# ### 5. User Experience:
#
# Consider giving feedback to the user in case their query does not return results or is ambiguous. You might want to suggest refined queries or correct potential typos.
#
# ---
#
# Here's a basic example using exact matching for a director-based query:
#
# ```python
# def execute_query(query):
#     # Tokenize the query
#     tokens = word_tokenize(query.lower())
#
#     # Check for director-based query
#     if 'directed' in tokens and 'by' in tokens:
#         director_name = ' '.join(tokens[tokens.index('by')+1:])
#         return df1[df1['Director'] == director_name]
#
#     # Add other query types
#     # ...
#
#     return None
#
# result = execute_query("Movies directed by Christopher Nolan")
# print(result)
# ```
#
# This is a very rudimentary example, but it gives you a starting point. The complexity of the system can grow as you incorporate more query types, handle synonyms (e.g., "films" vs "movies"), or deal with compound queries (e.g., "Romantic movies from the 90s starring Julia Roberts").
#
# The real power comes when you integrate machine learning or deep learning models, but that requires more computational resources and a more extensive setup. For a college project, starting with a rule-based system and progressively adding complexity is a good approach.
